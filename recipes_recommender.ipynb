# %% [markdown]
# # Capstone Term 2 - Project
#
# * Marcos Bittencourt
# ---
# * Contributors
#     * Todd McCullough [Git](https://github.com/tamccullough)
#     * Savya Sharma [Git](https://github.com/SavyaSharma)
#     * Marko Topitch [Git](https://github.com/TopMarko)
# ---

# %% [markdown]
# ### Initialize Modules and Data

# %% [markdown]
# ##### Import the Needed Modules

# %%
import pandas as pd
import numpy as np
import heapq
from math import floor

# %% [markdown]
# ##### Import Surprise
# [Surprise](http://surpriselib.com/) is a Python scikit building and analyzing recommender systems that deal with explicit rating data.

# %%
from surprise import Reader, Dataset
from surprise import KNNWithMeans

# %% [markdown]
# ##### Import Data

# %%
recipes_df = pd.read_csv('datasets/recipes-sub.csv')
users_df = pd.read_csv('datasets/users-sub.csv')
master_ratings_df = pd.read_csv('datasets/reviews-sub.csv')

# %%
recipes_df.columns
# Out:
# Index(['recipe_id', 'title', 'servings', 'cals_per_serving', 'prep_time',
#        'cook_time', 'ready_time', 'nutrition', 'ingredients', 'url'],
#       dtype='object')

# %%
recipes_df.head()
# Out:
#    recipe_id                         title  servings  cals_per_serving  \
# 0          1  Chocolate Sandwich Cookies I        12             600.0
# 1          2           Chocolate Pizzelles        12             358.0
# 2          3       Cookie Press Shortbread        24             116.0
# 3          4          Brown Sugar Frosting        16              59.0
# 4          5             Butter Cookies II        36             103.0
#
#     prep_time   cook_time ready_time  \
# 0  30 Minutes   8 Minutes   1 h 10 m
# 1        None        None       None
# 2  25 Minutes  10 Minutes       35 m
# 3        None        None       None
# 4  15 Minutes  10 Minutes   1 h 40 m
#
#                                            nutrition  \
# 0  Per Serving: 600 calories;26.9 g fat;86.6g car...
# 1  Per Serving: 358 calories;22.6 g fat;35.5g car...
# 2  Per Serving: 116 calories;7.8 g fat;10.9g carb...
# 3  Per Serving: 59 calories;0 g fat;15.2g carbohy...
# 4  Per Serving: 103 calories;5.3 g fat;12.7g carb...
#
#                                          ingredients  \
# 0  3 cups all-purpose flour;1 1/2 cups white suga...
# 1  4 eggs;1/4 cup cocoa powder;1 cup white sugar;...
# 2  1 cup butter;1 1/2 cups all-purpose flour;1/2 ...
# 3  1/2 cup packed dark brown sugar;1 tablespoon w...
# 4  1 cup butter;1 cup white sugar;1 egg;2 2/3 cup...
#
#                                                  url
# 0  https://www.allrecipes.com/recipe/10000/chocol...
# 1  https://www.allrecipes.com/recipe/10001/chocol...
# 2  https://www.allrecipes.com/recipe/10003/cookie...
# 3  https://www.allrecipes.com/recipe/10009/brown-...
# 4  https://www.allrecipes.com/recipe/10011/butter...

# %%
users_df.head()
# Out:
#    user_id        AR_id                                         link
# 0        1  naples34102  https://www.allrecipes.com/cook/naples34102
# 1        2      1207425      https://www.allrecipes.com/cook/1207425
# 2        3       183259       https://www.allrecipes.com/cook/183259
# 3        4       162514       https://www.allrecipes.com/cook/162514
# 4        5      1159515      https://www.allrecipes.com/cook/1159515

# %%
master_ratings_df.head()
# Out:
#    reviewer_id  recipe_id  rating        date  \
# 0            1          1       5  2012-02-16
# 1            2          1       2  2004-11-27
# 2            1          1       5  2012-02-16
# 3            3          1       4  2003-08-05
# 4            2          1       2  2004-11-27
#
#                                                 link
# 0  https://www.allrecipes.com/recipe/10000/chocol...
# 1  https://www.allrecipes.com/recipe/10000/chocol...
# 2  https://www.allrecipes.com/recipe/10000/chocol...
# 3  https://www.allrecipes.com/recipe/10000/chocol...
# 4  https://www.allrecipes.com/recipe/10000/chocol...

# %% [markdown]
# ### Data Cleaning

# %%
ratings_df = master_ratings_df.copy()
ratings_df.pop('date')
ratings_df.pop('link')
ratings_df.columns = ['user', 'item', 'rating']

# %%
ratings_df.head()
# Out:
#    user  item  rating
# 0     1     1       5
# 1     2     1       2
# 2     1     1       5
# 3     3     1       4
# 4     2     1       2

# %% [markdown]
# ##### Clean the ratings (Remove duplicates)
#
# Likes change, and making a recipe a few time can change a users rating. This means that users can rate a recipe multiple times. You can see this in the ratings_df.head() above.
#
# For a recommandation system it is best to only use one rating per user.
# For this system, only their most recent review on an item is kept.

# %%
values = ratings_df.values.tolist()
used_user_item_pairs = []

# TODO: Optimize this
clean_values = []
for value in values:
    if value[:2] not in used_user_item_pairs:
        used_user_item_pairs.append(value[:2])
        clean_values.append(value)
    else:
        clean_values[used_user_item_pairs.index(value[:2])] = value

clean_ratings_df = pd.DataFrame(clean_values, columns=['user', 'item', 'rating'])

# %% [markdown]
# The results after cleaning the ratings.

# %%
clean_ratings_df.head()
# Out:
#    user  item  rating
# 0     1     1       5
# 1     2     1       2
# 2     3     1       4
# 3     4     1       5
# 4     5     1       3

# %% [markdown]
# ##### Define a Ratings scale
# This scale is determined by the lowest and highest rating possible.
# In this case the lowest rating is 1, while the highest is 5.

# %%
reader = Reader(rating_scale=(1,5)) # This just defines the rating scale
data = Dataset.load_from_df(clean_ratings_df[['user', 'item', 'rating']], reader=reader)

# %% [markdown]
# ### Build the model
#
# ##### KNN with Means - Surprise
#
# [KNN with Means](https://surprise.readthedocs.io/en/stable/knn_inspired.html#surprise.prediction_algorithms.knns.KNNWithMeans) has been chosen for the recommender, which is a basic collaborative filtering algorithm, taking into account the mean ratings of each user.

# %%
def build_recommender(user_based=False, sim_type='cosine'):
    sim_options = {
        "name": sim_type,
        "user_based": user_based
    }

    return KNNWithMeans(sim_options=sim_options)

# %% [markdown]
# ##### Calculate the Similarity Matrix
#
# Ignoring folds this builds the *Trainset* using [build_full_trainset()](https://surprise.readthedocs.io/en/stable/dataset.html#surprise.dataset.DatasetAutoFolds.build_full_trainset)
#
# The Trainset is built using the data, but then contains more information about the data

# %%
trainset = data.build_full_trainset()

# user_based_recommender = build_recommender(user_based=True)
item_based_recommender = build_recommender()

# User based seems to give a memory error when fit, due to the much larger amount of users than recipes.
# user_based_recommender.fit(trainset)
item_based_recommender.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ##### Prediction
#
# Using this test to see how a users might rate a specific recipe.

# %%
i = 1
for i in range(150):
    prediction = item_based_recommender.predict(i,167)
    print(round(prediction.est,2), end=', ')
    i = i + 1
# Out:
# 4.46, 4.22, 2.97, 4.63, 4.99, 5, 4.63, 4.63, 4.63, 4.63, 4.63, 4.23, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 5, 4.63, 4.63, 4.63, 4.63, 4.63, 4.23, 4.97, 4.63, 5, 4.25, 4.63, 5, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.42, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 4.63, 5, 3.64, 4.64, 5, 4.3, 5, 5, 5, 4.64, 2.64, 5, 5, 5, 5, 5, 4.64, 5, 1.64, 2.64, 5, 5, 5, 4.41, 5, 5, 4.64, 4.64, 2.64, 5, 3.64, 1.64, 1.64, 1.64, 3.64, 4.64, 3.64, 4.82, 5, 2.64, 2.64, 2.64, 1.64, 5, 5, 5, 5, 5, 4.64, 4.64, 4.64, 4.64, 5, 5, 5, 5, 4.64, 5, 5, 4.64, 5, 2.64, 1.64, 5, 5, 4.64, 5, 5, 5, 3.64, 4.39, 5, 4.95, 4.99, 4.49, 4.38, 5, 5, 5, 5, 4.64, 4.64, 5, 2.64, 1.64, 5, 2.64, 5, 4.64, 4.64, 5, 5, 4.51, 5, 4.64, 3.64, 5, 5,

# %% [markdown]
# ### Inference
#
# Here is the meat and potatoes(har) of the whole thing.

# %%
def get_r(user_id):
    # Select which system to use. Due to memory constraints, item based is the only viable option
    recommender_system = item_based_recommender

    # User to recommend for
    #user_id = 562

    # N will represent how many items to recommend
    N = 200

    # The setting to a set and back to list is a failsafe.
    rated_items = list(set(clean_ratings_df.loc[clean_ratings_df['user'] == user_id]['item'].tolist()))

    # Self explanitory name
    all_item_ids = list(set(clean_ratings_df['item'].tolist()))

    # New_items just represents all the items not rated by the user
    new_items = [x for x in all_item_ids if x not in rated_items]

    # Estimate ratings for all unrated items
    predicted_ratings = {}
    for item_id in new_items:
        predicted_ratings[item_id] = recommender_system.predict(user_id, item_id).est
        pass

    # Get the item_ids for the top ratings
    recommended_ids = heapq.nlargest(N, predicted_ratings, key=predicted_ratings.get)
    recommended_ids = sorted(recommended_ids)

    # predicted_ratings
    recommended_df = recipes_df.loc[recipes_df['recipe_id'].isin(recommended_ids)].copy()
    recommended_df.set_index('recipe_id', inplace=True)
    recommended_df.insert(1, 'pred_rating', np.zeros(len(recommended_ids)))
    # recommended_df = recipes_df.copy()
    for idx,item_id in enumerate(recommended_ids):
        recommended_df.iloc[idx, recommended_df.columns.get_loc('pred_rating')] =predicted_ratings[item_id]
        pass

    return recommended_df.head(N).sort_values('pred_rating', ascending=False)

# %% [markdown]
# ### Get a Recommendation Based on Ingredients
#
# The final code that will be impletented in a cleaner fashion through the browser interface.

# %%
# ask the user for input
# get their ID number
user_id = int(input('Enter user id: '))

# get them to list some ingredients, currently it breaks if the second or next ingredient is not there
ingredient_list = input('Enter the ingredients separated by commas that you have on hand: ')

# split the input up into an array for the loop
items = np.array(ingredient_list.split(','))

# get the lowest rating
rating = int(input('Enter the lowest rating you\'ll accept: '))

# get their user name
user_name = users_df.loc[users_df['user_id'] == user_id]

# print some details
print('\nuser: ',user_name.iloc[0,1])
print(ingredient_list)
print('\nHere are your recommendations.')
test = get_r(user_id)
for item in items:
    test = test[test['ingredients'].str.contains(item)]
test = test[test['pred_rating'] >= rating]
test
# Out:
# Enter user id: 34
# Enter the ingredients separated by commas that you have on hand: chocolate
# Enter the lowest rating you'll accept: 3
#
# user:  214950
# chocolate
#
# Here are your recommendations.
#                                                       title  pred_rating  \
# recipe_id
# 14                 Allison's Supreme Chocolate Chip Cookies     5.000000
# 659                                     Caramel Brownies II     5.000000
# 689                       Crisp Rice Chocolate Chip Cookies     5.000000
# 691                                   Butterfinger Chunkies     5.000000
# 701                         Chocolate Mint Dessert Brownies     5.000000
# 707                                     Brownies To Die For     5.000000
# 579                                    Buffalo Chip Cookies     5.000000
# 430                                      Candy Bar Brownies     5.000000
# 438        Candy-Coated Milk Chocolate Pieces Party Cookies     5.000000
# 483                           Anna's Chocolate Chip Cookies     5.000000
# 526                                       Cowboy Cookies II     5.000000
# 17                          Easy Chocolate Bundt Cake Glaze     5.000000
# 779                       Disappearing Marshmallow Brownies     5.000000
# 421                         Chocolate Peanut Butter Squares     5.000000
# 900                                         Candy Bar Pie I     5.000000
# 966                                   Chocolate Praline Pie     5.000000
# 992                                   Chocolate Oatmeal Pie     5.000000
# 803                                Chocolate Thumbprints II     5.000000
# 873                                    Chocolate Chip Pie I     5.000000
# 878                           Chocolate Peanut Butter Pie I     5.000000
# 426                             Best Chocolate Chip Cookies     5.000000
# 312                                        Brownie Biscotti     5.000000
# 310                                 Best Chocolate Chippers     5.000000
# 163                                        Colossal Cookies     5.000000
# 91                                        Blonde Brownies I     5.000000
# 168                           Beth's Chocolate Chip Cookies     5.000000
# 169                    Easy Chocolate Cream Cheese Frosting     5.000000
# 79                                Chocolate Cherry Biscotti     5.000000
# 189                    Aunt Cora's World's Greatest Cookies     5.000000
# 239                                Chocolate Mint Cookies I     5.000000
# 195                       Deluxe Chocolate Marshmallow Bars     5.000000
# 341                        Caramel Filled Chocolate Cookies     5.000000
# 372                                  Crunchy Chocolate Bars     5.000000
# 401                              Chocolate Meringue Cookies     5.000000
# 359                     Chocolate Chocolate Chip Cookies II     5.000000
# 358                      Best Ever Chocolate Chip Cookies I     5.000000
# 143                              Becky's Oatmeal Carmelitas     5.000000
# 628                                    Crunchy Chip Cookies     4.929487
# 895                                Easy Chocolate Pecan Pie     4.900000
# 87                                   Chocolate Nut Biscotti     4.888889
# 548                    Chocolate Wafer Ice Cream Sandwiches     4.888889
# 902                          Chocolate Peanut Butter Pie II     4.802469
# 365                                                Bun Bars     4.800000
# 997                                      Chocolate Mint Pie     4.769231
# 639                   Chocolate Chocolate Chip Cake Cookies     4.753247
# 382                                       Chocolate Doodles     4.750000
# 89                 Chocolate Covered Cherry Cookie Frosting     4.750000
# 608                                         Cyclops Cookies     4.723404
# 903                                    Chocolate Banana Pie     4.720930
#
#            servings  cals_per_serving   prep_time   cook_time ready_time  \
# recipe_id
# 14               24             294.0  15 Minutes  12 Minutes       40 m
# 659              18             364.0        None        None       None
# 689              18             187.0        None        None       None
# 691              12             477.0        None        None       None
# 701              24             286.0  15 Minutes  30 Minutes    2 h 5 m
# 707              36             174.0  15 Minutes  35 Minutes       50 m
# 579              24             514.0        None        None       None
# 430               6             841.0        None        None       None
# 438              48             120.0        None        None       None
# 483              48             120.0  15 Minutes  10 Minutes       25 m
# 526              66             102.0        None        None       None
# 17               12             173.0   5 Minutes   5 Minutes       10 m
# 779              24             179.0  20 Minutes  20 Minutes       40 m
# 421              18             482.0        None        None       None
# 900               8             508.0        None        None       None
# 966               8             551.0        None        None       None
# 992               8             462.0        None        None       None
# 803              24             215.0        None        None       None
# 873               8             662.0  20 Minutes     1 Hour    1 h 20 m
# 878               8             861.0  30 Minutes        None        2 h
# 426              24             298.0  20 Minutes  10 Minutes        1 h
# 312              30              91.0  30 Minutes  45 Minutes   1 h 55 m
# 310              48             204.0  15 Minutes  15 Minutes        1 h
# 163              48             184.0  15 Minutes  12 Minutes        1 h
# 91                6             477.0  30 Minutes  20 Minutes       50 m
# 168              72             112.0  15 Minutes  12 Minutes       30 m
# 169              24              80.0        None        None       None
# 79               36             114.0  25 Minutes  40 Minutes   1 h 15 m
# 189              48             154.0  15 Minutes  15 Minutes   1 h 45 m
# 239              18             364.0        None        None       None
# 195              18             409.0        None        None       None
# 341              24             253.0  20 Minutes  10 Minutes        3 h
# 372              24             126.0        None        None       None
# 401              18              47.0        None        None       None
# 359              12             467.0  20 Minutes  10 Minutes        1 h
# 358              84             191.0  20 Minutes  15 Minutes   1 h 35 m
# 143              24             352.0  20 Minutes  30 Minutes       50 m
# 628              18             205.0        None        None       None
# 895               8             639.0  30 Minutes     1 Hour    1 h 30 m
# 87               18               NaN        None        None       None
# 548              15             252.0  10 Minutes        None   1 h 10 m
# 902               8             275.0        None        None       None
# 365              12            1292.0        None        None       None
# 997               8             541.0        None        None       None
# 639              24             265.0        None        None       None
# 382              36             131.0        None        None       None
# 89               18             103.0        None        None       None
# 608              24             196.0        None        None       None
# 903               8             573.0  30 Minutes  30 Minutes    1 d 1 h
#
#                                                    nutrition  \
# recipe_id
# 14         Per Serving: 294 calories;16.5 g fat;35.4g car...
# 659        Per Serving: 364 calories;18.8 g fat;47.6g car...
# 689        Per Serving: 187 calories;8.3 g fat;27.7g carb...
# 691        Per Serving: 477 calories;25.9 g fat;56.5g car...
# 701        Per Serving: 286 calories;13.8 g fat;39.5g car...
# 707        Per Serving: 174 calories;10.1 g fat;21.5g car...
# 579        Per Serving: 514 calories;22.7 g fat;75.6g car...
# 430        Per Serving: 841 calories;40.5 g fat;112.3g ca...
# 438        Per Serving: 120 calories;5.9 g fat;15.7g carb...
# 483        Per Serving: 120 calories;6.2 g fat;16g carboh...
# 526        Per Serving: 102 calories;5 g fat;14.1g carboh...
# 17         Per Serving: 173 calories;7 g fat;26.7g carboh...
# 779        Per Serving: 179 calories;8.5 g fat;24.5g carb...
# 421        Per Serving: 482 calories;33.3 g fat;43.4g car...
# 900        Per Serving: 508 calories;39.1 g fat;38.2g car...
# 966        Per Serving: 551 calories;37.3 g fat;53g carbo...
# 992        Per Serving: 462 calories;16.4 g fat;79.4g car...
# 803        Per Serving: 215 calories;12.3 g fat;25.4g car...
# 873        Per Serving: 662 calories;47.6 g fat;57.6g car...
# 878        Per Serving: 861 calories;63.1 g fat;67.8g car...
# 426        Per Serving: 298 calories;15.6 g fat;38.8g car...
# 312        Per Serving: 91 calories;4.2 g fat;12.6g carbo...
# 310        Per Serving: 204 calories;12.4 g fat;22.5g car...
# 163        Per Serving: 184 calories;8.8 g fat;24g carboh...
# 91         Per Serving: 477 calories;23.2 g fat;65.4g car...
# 168        Per Serving: 112 calories;6.4 g fat;13.6g carb...
# 169        Per Serving: 80 calories;6.3 g fat;6g carbohyd...
# 79         Per Serving: 114 calories;4.6 g fat;16.6g carb...
# 189        Per Serving: 154 calories;8.8 g fat;18.2g carb...
# 239        Per Serving: 364 calories;15.9 g fat;55.6g car...
# 195        Per Serving: 409 calories;23.8 g fat;47.2g car...
# 341        Per Serving: 253 calories;13 g fat;33.1g carbo...
# 372        Per Serving: 126 calories;8.4 g fat;12.8g carb...
# 401        Per Serving: 47 calories;1 g fat;9.6g carbohyd...
# 359        Per Serving: 467 calories;25.2 g fat;61.6g car...
# 358        Per Serving: 191 calories;9.2 g fat;26.6g carb...
# 143        Per Serving: 352 calories;17.3 g fat;48.6g car...
# 628        Per Serving: 205 calories;8.4 g fat;32.7g carb...
# 895        Per Serving: 639 calories;38.6 g fat;75.2g car...
# 87                                                       NaN
# 548        Per Serving: 252 calories;13.1 g fat;34.8g car...
# 902        Per Serving: 275 calories;13.6 g fat;35.8g car...
# 365        Per Serving: 1292 calories;77.4 g fat;137.8g c...
# 997        Per Serving: 541 calories;29.5 g fat;56.5g car...
# 639        Per Serving: 265 calories;15.9 g fat;31.3g car...
# 382        Per Serving: 131 calories;5 g fat;20.8g carboh...
# 89         Per Serving: 103 calories;4.3 g fat;16.9g carb...
# 608        Per Serving: 196 calories;9.8 g fat;25.2g carb...
# 903        Per Serving: 573 calories;36 g fat;60.5g carbo...
#
#                                                  ingredients  \
# recipe_id
# 14         1/2 cup shortening;1/2 cup butter, softened;3/...
# 659        1 (14 ounce) package individually wrapped cara...
# 689        1 1/2 cups all-purpose flour;1/2 teaspoon baki...
# 691        1/2 cup butter, softened;3/4 cup white sugar;2...
# 701        1 cup white sugar;1/2 cup butter, softened;4 e...
# 707        1 (19.8 ounce) package brownie mix;1 cup sour ...
# 579        2 cups margarine, melted;2 cups packed brown s...
# 430        1 (18.25 ounce) package German chocolate cake ...
# 438        1 cup shortening;1 cup packed brown sugar;1/2 ...
# 483        1 cup butter;1/2 cup white sugar;1 cup packed ...
# 526        2 cups all-purpose flour;1 teaspoon baking sod...
# 17         1 (14 ounce) can sweetened condensed milk;1 cu...
# 779        1/2 cup butter;1 cup butterscotch chips;2/3 cu...
# 421        1 cup butter;4 cups confectioners' sugar;2 cup...
# 900        3 tablespoons butter;1 1/2 cups ground walnuts...
# 966        2 eggs;1 egg yolk;1 cup white sugar;4 tablespo...
# 992        2 eggs;1 cup white sugar;1/4 teaspoon salt;1 c...
# 803        1 cup butter;1 cup white sugar;2 eggs, separat...
# 873        2 eggs;1/2 cup white sugar;1/2 cup packed brow...
# 878        1 (9 inch) prepared chocolate cookie crumb cru...
# 426        1 cup butter, softened;1 cup white sugar;1 cup...
# 312        1/3 cup butter, softened;2/3 cup white sugar;2...
# 310        1 cup butter;1 cup vegetable oil;1 cup white s...
# 163        1/2 cup margarine, softened;1 1/2 cups white s...
# 91         1 cup sifted all-purpose flour;1/2 teaspoon ba...
# 168        2/3 cup butter flavored shortening;2/3 cup but...
# 169        1 (8 ounce) package cream cheese;1/4 cup confe...
# 79         1/2 cup butter, softened;3/4 cup white sugar;3...
# 189        1 cup margarine, softened;1 cup peanut butter;...
# 239        3/4 cup butter;1 1/2 cups packed brown sugar;2...
# 195        3/4 cup butter;1 1/2 cups white sugar;3 eggs;1...
# 341        1 cup butter, softened;1 cup white sugar;1 cup...
# 372        2 cups semisweet chocolate chips;3/4 cup crunc...
# 401        3 egg whites;1/8 teaspoon cream of tartar;1/2 ...
# 359        2 cups all-purpose flour;1/2 cup cocoa powder;...
# 358        3 cups margarine, softened;2 1/2 cups white su...
# 143        1 (14 ounce) package individually wrapped cara...
# 628        1 1/4 cups all-purpose flour;1/2 teaspoon baki...
# 895        1 (9 inch) unbaked pie crust;1/3 cup butter;2/...
# 87         2 cups all-purpose flour;1 1/2 teaspoons bakin...
# 548        1 (9 ounce) box chocolate wafer cookies;1 quar...
# 902        1 (9 inch) prepared graham cracker crust;2 (4 ...
# 365        2 cups semisweet chocolate chips;2 cups butter...
# 997        1 1/2 cups crushed chocolate sandwich cookies;...
# 639        1 cup unsalted butter;1 1/2 cups white sugar;2...
# 382        1/2 cup vegetable oil;4 (1 ounce) squares unsw...
# 89         1/2 cup milk;1/4 cup butter;2 (1 ounce) square...
# 608        1/2 cup butter;1/2 cup peanut butter;1/2 cup w...
# 903        1 recipe pastry for a 9 inch single crust pie;...
#
#                                                          url
# recipe_id
# 14         https://www.allrecipes.com/recipe/10032/alliso...
# 659        https://www.allrecipes.com/recipe/11242/carame...
# 689        https://www.allrecipes.com/recipe/11329/crisp-...
# 691        https://www.allrecipes.com/recipe/11333/butter...
# 701        https://www.allrecipes.com/recipe/11363/chocol...
# 707        https://www.allrecipes.com/recipe/11375/browni...
# 579        https://www.allrecipes.com/recipe/11090/buffal...
# 430        https://www.allrecipes.com/recipe/10822/candy-...
# 438        https://www.allrecipes.com/recipe/10841/candy-...
# 483        https://www.allrecipes.com/recipe/10909/annas-...
# 526        https://www.allrecipes.com/recipe/10989/cowboy...
# 17         https://www.allrecipes.com/recipe/100335/easy-...
# 779        https://www.allrecipes.com/recipe/11574/disapp...
# 421        https://www.allrecipes.com/recipe/10804/chocol...
# 900        https://www.allrecipes.com/recipe/12134/candy-...
# 966        https://www.allrecipes.com/recipe/12369/chocol...
# 992        https://www.allrecipes.com/recipe/12447/chocol...
# 803        https://www.allrecipes.com/recipe/11640/chocol...
# 873        https://www.allrecipes.com/recipe/12077/chocol...
# 878        https://www.allrecipes.com/recipe/12085/chocol...
# 426        https://www.allrecipes.com/recipe/10813/best-c...
# 312        https://www.allrecipes.com/recipe/10595/browni...
# 310        https://www.allrecipes.com/recipe/10592/best-c...
# 163        https://www.allrecipes.com/recipe/10319/coloss...
# 91         https://www.allrecipes.com/recipe/10177/blonde...
# 168        https://www.allrecipes.com/recipe/10337/beths-...
# 169        https://www.allrecipes.com/recipe/10342/easy-c...
# 79         https://www.allrecipes.com/recipe/10158/chocol...
# 189        https://www.allrecipes.com/recipe/10380/aunt-c...
# 239        https://www.allrecipes.com/recipe/10477/chocol...
# 195        https://www.allrecipes.com/recipe/10388/deluxe...
# 341        https://www.allrecipes.com/recipe/10642/carame...
# 372        https://www.allrecipes.com/recipe/10691/crunch...
# 401        https://www.allrecipes.com/recipe/10751/chocol...
# 359        https://www.allrecipes.com/recipe/10666/chocol...
# 358        https://www.allrecipes.com/recipe/10664/best-e...
# 143        https://www.allrecipes.com/recipe/10271/beckys...
# 628        https://www.allrecipes.com/recipe/11183/crunch...
# 895        https://www.allrecipes.com/recipe/12122/easy-c...
# 87         https://www.allrecipes.com/recipe/10170/chocol...
# 548        https://www.allrecipes.com/recipe/110311/choco...
# 902        https://www.allrecipes.com/recipe/12143/chocol...
# 365        https://www.allrecipes.com/recipe/10680/bun-bars/
# 997        https://www.allrecipes.com/recipe/12470/chocol...
# 639        https://www.allrecipes.com/recipe/11203/chocol...
# 382        https://www.allrecipes.com/recipe/10714/chocol...
# 89         https://www.allrecipes.com/recipe/10172/chocol...
# 608        https://www.allrecipes.com/recipe/11140/cyclop...
# 903        https://www.allrecipes.com/recipe/12149/chocol...

# %%
rec_df = pd.read_csv('recipes-sub.csv')
u_df = pd.read_csv('users-sub.csv')
r_df = pd.read_csv('reviews-sub.csv')

# %%
a = 99
r_df.loc[master_ratings_df['reviewer_id'] == a]
# Out:
#      reviewer_id  recipe_id  rating        date  \
# 104           99          3       5  2010-11-21
#
#                                                   link
# 104  https://www.allrecipes.com/recipe/getreviews/r...
